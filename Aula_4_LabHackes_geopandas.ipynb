# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosangelafl/Eleicoes2018_geopandas/blob/master/Aula_4_LabHackes_geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install geopandas

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
df_mapa = gpd.read_file('/content/drive/My Drive/Curso LabHacker/shapefile_ibge _aula4/BRMUE250GC_SIR.shp')

# %%
df_mapa.head()
# Out:
#                    NM_MUNICIP  ...                                           geometry
# 0                       CAIUÁ  ...  POLYGON ((-51.86001 -21.58072, -51.85892 -21.5...
# 1                    CASTILHO  ...  POLYGON ((-51.41936 -20.68108, -51.41942 -20.6...
# 2                     DRACENA  ...  POLYGON ((-51.48515 -21.42765, -51.48500 -21.4...
# 3            ESTRELA DO NORTE  ...  POLYGON ((-51.57097 -22.39887, -51.57099 -22.3...
# 4  EUCLIDES DA CUNHA PAULISTA  ...  POLYGON ((-52.44569 -22.60828, -52.44569 -22.6...
#
# [5 rows x 3 columns]

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  5572 non-null   object
#  1   CD_GEOCMU   5572 non-null   object
#  2   geometry    5572 non-null   geometry
# dtypes: geometry(1), object(2)
# memory usage: 130.7+ KB

# %%
#plotando o mapa
df_mapa.plot()

# %%
#expandir o desenho do mapa
fig, ax = plt.subplots(1, figsize=(12,12))

#desenhar o mapa
df_mapa.plot(ax=ax)

#tirar os eixos
ax.set_axis_off()
plt.show()

# %%
df_votacao = pd.read_csv('/content/drive/My Drive/Curso LabHacker/shapefile_ibge _aula4/votacao_candidato_munzona_2018_BRASIL.csv', sep=';', encoding='Latin-1')
df_votacao.head()
# Out:
#    DT_GERACAO HH_GERACAO  ...  ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 0  01/08/2019   15:43:50  ...                    N                  4
# 1  01/08/2019   15:43:50  ...                    N                  0
# 2  01/08/2019   15:43:50  ...                    N                  0
# 3  01/08/2019   15:43:50  ...                    N                  1
# 4  01/08/2019   15:43:50  ...                    N                  0
#
# [5 rows x 38 columns]

# %%
df_votacao.columns
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'CD_CARGO', 'DS_CARGO', 'SQ_CANDIDATO',
#        'NR_CANDIDATO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO',
#        'NM_SOCIAL_CANDIDATO', 'CD_SITUACAO_CANDIDATURA',
#        'DS_SITUACAO_CANDIDATURA', 'CD_DETALHE_SITUACAO_CAND',
#        'DS_DETALHE_SITUACAO_CAND', 'TP_AGREMIACAO', 'NR_PARTIDO', 'SG_PARTIDO',
#        'NM_PARTIDO', 'SQ_COLIGACAO', 'NM_COLIGACAO', 'DS_COMPOSICAO_COLIGACAO',
#        'CD_SIT_TOT_TURNO', 'DS_SIT_TOT_TURNO', 'ST_VOTO_EM_TRANSITO',
#        'QT_VOTOS_NOMINAIS'],
#       dtype='object')

# %%
df_votacao.dtypes
# Out:
# DT_GERACAO                  object
# HH_GERACAO                  object
# ANO_ELEICAO                  int64
# CD_TIPO_ELEICAO              int64
# NM_TIPO_ELEICAO             object
# NR_TURNO                     int64
# CD_ELEICAO                   int64
# DS_ELEICAO                  object
# DT_ELEICAO                  object
# TP_ABRANGENCIA              object
# SG_UF                       object
# SG_UE                       object
# NM_UE                       object
# CD_MUNICIPIO                 int64
# NM_MUNICIPIO                object
# NR_ZONA                      int64
# CD_CARGO                     int64
# DS_CARGO                    object
# SQ_CANDIDATO                 int64
# NR_CANDIDATO                 int64
# NM_CANDIDATO                object
# NM_URNA_CANDIDATO           object
# NM_SOCIAL_CANDIDATO         object
# CD_SITUACAO_CANDIDATURA      int64
# DS_SITUACAO_CANDIDATURA     object
# CD_DETALHE_SITUACAO_CAND     int64
# DS_DETALHE_SITUACAO_CAND    object
# TP_AGREMIACAO               object
# NR_PARTIDO                   int64
# SG_PARTIDO                  object
# NM_PARTIDO                  object
# SQ_COLIGACAO                 int64
# NM_COLIGACAO                object
# DS_COMPOSICAO_COLIGACAO     object
# CD_SIT_TOT_TURNO             int64
# DS_SIT_TOT_TURNO            object
# ST_VOTO_EM_TRANSITO         object
# QT_VOTOS_NOMINAIS            int64
# dtype: object

# %%
df_votacao['CD_MUNICIPIO'] = df_votacao.CD_MUNICIPIO.astype(object)

# %%
df_votacao = df_votacao[df_votacao['DS_CARGO'] == 'Presidente']

# %%
#separar os dados ficando apenas com os dados de segundo turno
df_votacao = df_votacao[df_votacao['NR_TURNO'] == 2]
df_votacao.sample()
# Out:
#          DT_GERACAO HH_GERACAO  ...  ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 3609220  01/08/2019   15:43:50  ...                    N              30832
# 3685208  01/08/2019   15:43:50  ...                    N               1167
# 3759743  01/08/2019   15:43:50  ...                    N              11611
# 3561866  01/08/2019   15:43:50  ...                    N               1734
# 6056691  01/08/2019   15:43:50  ...                    N               1245
# 7644173  01/08/2019   15:43:50  ...                    N               2081
# 3873834  01/08/2019   15:43:50  ...                    N              79199
# 3757857  01/08/2019   15:43:50  ...                    N               2732
# 8050286  01/08/2019   15:43:50  ...                    N               4427
# 4323403  01/08/2019   15:43:50  ...                    N                869
#
# [10 rows x 38 columns]

# %%
#Verificando a qtd de municípios com nunique()
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5741

# %%
#verificar cidades fora do Brasil
df_votacao[df_votacao['SG_UF'] == 'ZZ'].sample(2).T
# Out:
#                                              2039574                                    4536963
# DT_GERACAO                                01/08/2019                                 01/08/2019
# HH_GERACAO                                  15:43:50                                   15:43:50
# ANO_ELEICAO                                     2018                                       2018
# CD_TIPO_ELEICAO                                    2                                          2
# NM_TIPO_ELEICAO                    Eleição Ordinária                          Eleição Ordinária
# NR_TURNO                                           2                                          2
# CD_ELEICAO                                       296                                        296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018                 ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018                                 28/10/2018
# TP_ABRANGENCIA                                     F                                          F
# SG_UF                                             ZZ                                         ZZ
# SG_UE                                             BR                                         BR
# NM_UE                                         BRASIL                                     BRASIL
# CD_MUNICIPIO                                   29939                                      29769
# NM_MUNICIPIO                              LIBREVILLE                                     HARARE
# NR_ZONA                                            1                                          1
# CD_CARGO                                           1                                          1
# DS_CARGO                                  Presidente                                 Presidente
# SQ_CANDIDATO                            280000629808                               280000614517
# NR_CANDIDATO                                      13                                         17
# NM_CANDIDATO                         FERNANDO HADDAD                     JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                    FERNANDO HADDAD                             JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                           #NULO#                                     #NULO#
# CD_SITUACAO_CANDIDATURA                           12                                         12
# DS_SITUACAO_CANDIDATURA                         APTO                                       APTO
# CD_DETALHE_SITUACAO_CAND                           2                                          2
# DS_DETALHE_SITUACAO_CAND                    DEFERIDO                                   DEFERIDO
# TP_AGREMIACAO                              Coligação                                  Coligação
# NR_PARTIDO                                        13                                         17
# SG_PARTIDO                                        PT                                        PSL
# NM_PARTIDO                 Partido dos Trabalhadores                     Partido Social Liberal
# SQ_COLIGACAO                            280000050703                               280000050386
# NM_COLIGACAO                    O POVO FELIZ DE NOVO  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO          PT / PC do B / PROS                                 PSL / PRTB
# CD_SIT_TOT_TURNO                                   4                                          1
# DS_SIT_TOT_TURNO                          NÃO ELEITO                                     ELEITO
# ST_VOTO_EM_TRANSITO                                N                                          N
# QT_VOTOS_NOMINAIS                                  0                                          0

# %%
df_votacao[df_votacao['SG_UF'] == 'ZZ']['CD_MUNICIPIO'].nunique()
# Out:
# 171

# %%
df_votacao = df_votacao[df_votacao['SG_UF'] != 'ZZ']

# %%
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5570

# %%
#Quantas zonas eleitorais tem em São Paulo
#df_votacao[df_votacao['NM_MUNICIPIO'] == 'SÃO PAULO'].head(2).T

# %%
df_votacao = df_votacao[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]
df_votacao.head()
# Out:
#     SG_UF CD_MUNICIPIO  ... NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 13     PE        25690  ...   FERNANDO HADDAD              16021
# 188    RJ        59013  ...    JAIR BOLSONARO              55877
# 191    BA        33952  ...    JAIR BOLSONARO               1521
# 591    MG        50512  ...   FERNANDO HADDAD               1277
# 592    PB        19194  ...   FERNANDO HADDAD               6334
#
# [5 rows x 6 columns]

# %%
#Agregar por municipios e candidatos
df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum()
# Out:
#                                                                           QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NR_CANDIDATO NM_URNA_CANDIDATO
# AC    1007         BUJARI                 13           FERNANDO HADDAD                 1274
#                                           17           JAIR BOLSONARO                  4676
#       1015         CAPIXABA               13           FERNANDO HADDAD                 1086
#                                           17           JAIR BOLSONARO                  3895
#       1023         PORTO ACRE             13           FERNANDO HADDAD                 2059
# ...                                                                                     ...
# TO    96954        ALIANÇA DO TOCANTINS   17           JAIR BOLSONARO                  1215
#       96970        APARECIDA DO RIO NEGRO 13           FERNANDO HADDAD                 1291
#                                           17           JAIR BOLSONARO                  1171
#       96997        BARROLÂNDIA            13           FERNANDO HADDAD                 1545
#                                           17           JAIR BOLSONARO                  1501
#
# [11140 rows x 1 columns]

# %%
df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum().reset_index()
# Out:
#       SG_UF  CD_MUNICIPIO  ... NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 0        AC          1007  ...   FERNANDO HADDAD               1274
# 1        AC          1007  ...    JAIR BOLSONARO               4676
# 2        AC          1015  ...   FERNANDO HADDAD               1086
# 3        AC          1015  ...    JAIR BOLSONARO               3895
# 4        AC          1023  ...   FERNANDO HADDAD               2059
# ...     ...           ...  ...               ...                ...
# 11135    TO         96954  ...    JAIR BOLSONARO               1215
# 11136    TO         96970  ...   FERNANDO HADDAD               1291
# 11137    TO         96970  ...    JAIR BOLSONARO               1171
# 11138    TO         96997  ...   FERNANDO HADDAD               1545
# 11139    TO         96997  ...    JAIR BOLSONARO               1501
#
# [11140 rows x 6 columns]

# %%
#ordenar o df pela quantidade votos nominais
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False).head(10)
# Out:
#         SG_UF CD_MUNICIPIO  ... NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 697528     SP        71072  ...    JAIR BOLSONARO             113283
# 8869466    SP        71072  ...   FERNANDO HADDAD             101722
# 1471670    SP        71072  ...    JAIR BOLSONARO              99260
# 6467922    SP        70998  ...    JAIR BOLSONARO              96266
# 6343245    SP        71072  ...    JAIR BOLSONARO              94034
# 6163623    SC        80470  ...    JAIR BOLSONARO              91391
# 1359561    SP        65110  ...    JAIR BOLSONARO              88374
# 7637713    SP        71072  ...    JAIR BOLSONARO              87993
# 8377685    SP        71072  ...    JAIR BOLSONARO              86995
# 2887407    SP        71072  ...    JAIR BOLSONARO              85566
#
# [10 rows x 6 columns]

# %%
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False,inplace=True)

# %%
# dropar as linhas duplicados, mas mantendo a primeira
df_votacao.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)
df_votacao.head(10)
# Out:
#         SG_UF CD_MUNICIPIO  ... NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 697528     SP        71072  ...    JAIR BOLSONARO             113283
# 6467922    SP        70998  ...    JAIR BOLSONARO              96266
# 6163623    SC        80470  ...    JAIR BOLSONARO              91391
# 1359561    SP        65110  ...    JAIR BOLSONARO              88374
# 5286400    PR        75353  ...    JAIR BOLSONARO              85202
# 6808127    SP        66192  ...    JAIR BOLSONARO              84952
# 3218479    TO        73440  ...    JAIR BOLSONARO              84782
# 1208160    AC         1392  ...    JAIR BOLSONARO              80106
# 8825173    DF        97012  ...    JAIR BOLSONARO              79794
# 3873834    RR         3018  ...    JAIR BOLSONARO              79199
#
# [10 rows x 6 columns]

# %%
df_votacao['RESULTADO'] = df_votacao['NR_CANDIDATO'].apply(lambda x: x== 17)

# %%
df_votacao.head(10)
# Out:
#         SG_UF CD_MUNICIPIO  ... QT_VOTOS_NOMINAIS  RESULTADO
# 697528     SP        71072  ...            113283       True
# 6467922    SP        70998  ...             96266       True
# 6163623    SC        80470  ...             91391       True
# 1359561    SP        65110  ...             88374       True
# 5286400    PR        75353  ...             85202       True
# 6808127    SP        66192  ...             84952       True
# 3218479    TO        73440  ...             84782       True
# 1208160    AC         1392  ...             80106       True
# 8825173    DF        97012  ...             79794       True
# 3873834    RR         3018  ...             79199       True
#
# [10 rows x 7 columns]

# %%
#recuperar a tabela de correspondência entre código do ibge do mapa e código TSE do df


url = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'
df_equivalencia = pd.read_csv(url)
df_equivalencia.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
#Vamos colocar o cód do ibge no df_votacao, usando merge
#preparando o dataframe
#vamos reindexar o df_votacao pelo código tse

df_vot_novo = df_votacao.copy()
df_vot_novo.set_index('CD_MUNICIPIO', drop=False, inplace=True)
df_vot_novo.head()
# Out:
#              SG_UF CD_MUNICIPIO  ... QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO                     ...
# 71072           SP        71072  ...            113283       True
# 70998           SP        70998  ...             96266       True
# 80470           SC        80470  ...             91391       True
# 65110           SP        65110  ...             88374       True
# 75353           PR        75353  ...             85202       True
#
# [5 rows x 7 columns]

# %%
#reindexar o df_equivalência pelo código ibge
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index('COD_TSE', drop=False, inplace=True)
df_equi_novo.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
df_vot_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   object
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 310.0+ KB

# %%
df_equi_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chave        5570 non-null   object
#  1   NOME         5570 non-null   object
#  2   UF           5570 non-null   object
#  3   GEOCOD_IBGE  5570 non-null   int64
#  4   COD_TSE      5570 non-null   int64
#  5   AJUSTE       29 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
#criando um novo df com base no merge dos dois dfs anteriores, votação e equivalência
df_vot_equi = df_vot_novo.join(df_equi_novo)
df_vot_equi.head()
# Out:
#              SG_UF CD_MUNICIPIO  ... COD_TSE  AJUSTE
# CD_MUNICIPIO                     ...
# 71072           SP        71072  ...   71072     NaN
# 70998           SP        70998  ...   70998     NaN
# 80470           SC        80470  ...   80470     NaN
# 65110           SP        65110  ...   65110     NaN
# 75353           PR        75353  ...   75353     NaN
#
# [5 rows x 13 columns]

# %%
#vamos juntar o df_mapa com o df_equi_novo

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   object
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   int64
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 731.1+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  5572 non-null   object
#  1   CD_GEOCMU   5572 non-null   object
#  2   geometry    5572 non-null   geometry
# dtypes: geometry(1), object(2)
# memory usage: 130.7+ KB

# %%
# Transformar a coluna de código de IBGE do df de votação/equivalência
df_vot_equi['GEOCOD_IBGE'] = df_vot_equi['GEOCOD_IBGE'].astype(str)

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   object
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   object
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(3), object(9)
# memory usage: 731.1+ KB

# %%
#unificando df_mapa  com o df Votação/equivalência, primeiro vamos reindexar o mapa
df_mapa.set_index('CD_GEOCMU', drop=False, inplace=True)

# %%
df_vot_equi.set_index('GEOCOD_IBGE', drop=False, inplace=True)

# %%
#vamos juntar os df
df_mapa_novo = df_mapa.join(df_vot_equi)

df_mapa_novo.head(3)
# Out:
#           NM_MUNICIP CD_GEOCMU  ...  COD_TSE AJUSTE
# CD_GEOCMU                       ...
# 3509106        CAIUÁ   3509106  ...  62839.0    NaN
# 3511003     CASTILHO   3511003  ...  63215.0    NaN
# 3514403      DRACENA   3514403  ...  63894.0    NaN
#
# [3 rows x 16 columns]

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 3509106 to 1101807
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NM_MUNICIP         5572 non-null   object
#  1   CD_GEOCMU          5572 non-null   object
#  2   geometry           5572 non-null   geometry
#  3   SG_UF              5570 non-null   object
#  4   CD_MUNICIPIO       5570 non-null   object
#  5   NM_MUNICIPIO       5570 non-null   object
#  6   NR_CANDIDATO       5570 non-null   float64
#  7   NM_URNA_CANDIDATO  5570 non-null   object
#  8   QT_VOTOS_NOMINAIS  5570 non-null   float64
#  9   RESULTADO          5570 non-null   object
#  10  chave              5570 non-null   object
#  11  NOME               5570 non-null   object
#  12  UF                 5570 non-null   object
#  13  GEOCOD_IBGE        5570 non-null   object
#  14  COD_TSE            5570 non-null   float64
#  15  AJUSTE             29 non-null     object
# dtypes: float64(3), geometry(1), object(12)
# memory usage: 900.0+ KB

# %%
df_mapa_novo[df_mapa_novo['NR_CANDIDATO'].isnull()]
# Out:
#                 NM_MUNICIP CD_GEOCMU  ... COD_TSE AJUSTE
# CD_GEOCMU                             ...
# 4300001        LAGOA MIRIM   4300001  ...     NaN    NaN
# 4300002    LAGOA DOS PATOS   4300002  ...     NaN    NaN
#
# [2 rows x 16 columns]

# %%
df_mapa_novo.drop(columns=['AJUSTE'], inplace=True)

# %%
#vamos eliminar info das duas lagoas do RS com dropna()
df_mapa_novo.dropna(inplace=True)

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(['red', 'green'])

#desenhando o mapa

fig, ax = plt.subplots(1, figsize=(12,12))
ax = df_mapa_novo.plot(column='RESULTADO', cmap=cmap, legend=True, linewidth=0.1, ax=ax, edgecolor='grey')

#escodendo os eixos

ax.set_axis_off()

#colocando título

ax.set_title('Resultado Eleição presidencial', fontdict={'fontsize':'25', 'fontweight': '3'})

#criando uma nota de rodape
ax.annotate('Fonte: IBGE, 2015; TSE, 2019; Estadão, 2019', xy=(0.1, 0.08), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top',fontsize=10,color='#555555')

#alterando a legenda
leg= ax.get_legend()
leg.get_texts()[0].set_text('Fernando Haddad')
leg.get_texts()[1].set_text('Jair Bolsonaro')

plt.show()
